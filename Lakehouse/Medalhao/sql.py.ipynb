# %%
import duckdb

con = duckdb.connect("nasa.duckdb")  # cria um banco local
con.register("nasa_weather_df", df)

# Cria uma tabela persistente
con.execute("""
CREATE TABLE nasa_weather AS
SELECT * FROM nasa_weather_df
""")
